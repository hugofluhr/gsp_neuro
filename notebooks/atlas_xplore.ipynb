# %%
import pandas as pd
import glob
import csv
import sys
from importlib import reload

sys.path.append("/home/localadmin/Bureau/HUGO/repositories/gsp_neuro/gsp_neuro")

import utils as ut
reload(ut)
# Out:
# <module 'utils' from '/home/localadmin/Bureau/HUGO/repositories/gsp_neuro/gsp_neuro/utils.py'>

# %%
data_path = "/home/localadmin/Bureau/HUGO/Hugo/"
atlas_file = "/home/localadmin/Bureau/HUGO/ParcellationLausanne2008.xls"

# %%
thickness_files = [file for file in glob.glob(data_path + "thickness-*")]
thickness_files.sort()

# %% [markdown]
# ### Check number of regions for each Scale

# %%
for file in thickness_files:
    regions = ut.regions_in_file(file)
# Out:
#    68 ROIs found
#   114 ROIs found
#   216 ROIs found
#   446 ROIs found
#  1002 ROIs found

# %%
current_file = thickness_files[1]
regions = ut.regions_in_file(current_file)
# Out:
#   114 ROIs found

# %%
df = pd.read_excel(atlas_file,sheet_name='LABELS', header=[0,1])
rh_atlas_labels = list(df['RIGHT HEMI','scale60 labels'].dropna())
lh_atlas_labels = list(df['LEFT HEMI','scale60 labels'].dropna())

# %%
df
# Out:
#      RIGHT HEMI                                                               \
#     scale500 ID          scale500 labels scale250 ID         scale250 labels
# 0             1   lateralorbitofrontal_9         1.0  lateralorbitofrontal_1
# 1             2  lateralorbitofrontal_11         2.0  lateralorbitofrontal_2
# 2             3   lateralorbitofrontal_5         3.0  lateralorbitofrontal_3
# 3             4   lateralorbitofrontal_6         4.0  lateralorbitofrontal_4
# 4             5   lateralorbitofrontal_7         5.0  lateralorbitofrontal_5
# ..          ...                      ...         ...                     ...
# 503         504                  putamen         NaN                     NaN
# 504         505                 pallidum         NaN                     NaN
# 505         506            accumbensarea         NaN                     NaN
# 506         507              hyppocampus         NaN                     NaN
# 507         508                 amygdala         NaN                     NaN
#
#                                                                             \
#     scale125 ID         scale125 labels scale60 ID          scale60 labels
# 0           1.0  lateralorbitofrontal_1        1.0  lateralorbitofrontal_1
# 1           2.0  lateralorbitofrontal_2        2.0  lateralorbitofrontal_2
# 2           3.0  lateralorbitofrontal_3        3.0         parsorbitalis_1
# 3           4.0  lateralorbitofrontal_4        4.0           frontalpole_1
# 4           5.0         parsorbitalis_1        5.0   medialorbitofrontal_1
# ..          ...                     ...        ...                     ...
# 503         NaN                     NaN        NaN                     NaN
# 504         NaN                     NaN        NaN                     NaN
# 505         NaN                     NaN        NaN                     NaN
# 506         NaN                     NaN        NaN                     NaN
# 507         NaN                     NaN        NaN                     NaN
#
#                                        LEFT HEMI                           \
#     scale33 ID        scale33 labels scale500 ID          scale500 labels
# 0          1.0  lateralorbitofrontal       509.0   lateralorbitofrontal_9
# 1          2.0         parsorbitalis       510.0   lateralorbitofrontal_4
# 2          3.0           frontalpole       511.0   lateralorbitofrontal_6
# 3          4.0   medialorbitofrontal       512.0   lateralorbitofrontal_3
# 4          5.0      parstriangularis       513.0  lateralorbitofrontal_13
# ..         ...                   ...         ...                      ...
# 503        NaN                   NaN      1012.0            accumbensarea
# 504        NaN                   NaN      1013.0              hyppocampus
# 505        NaN                   NaN      1014.0                 amygdala
# 506        NaN                   NaN      1015.0                brainstem
# 507        NaN                   NaN         NaN                      NaN
#
#                                                                              \
#     scale250 ID         scale250 labels scale125 ID         scale125 labels
# 0         231.0  lateralorbitofrontal_1       116.0  lateralorbitofrontal_1
# 1         232.0  lateralorbitofrontal_2       117.0  lateralorbitofrontal_2
# 2         233.0  lateralorbitofrontal_3       118.0  lateralorbitofrontal_3
# 3         234.0  lateralorbitofrontal_4       119.0  lateralorbitofrontal_4
# 4         235.0  lateralorbitofrontal_5       120.0         parsorbitalis_1
# ..          ...                     ...         ...                     ...
# 503         NaN                     NaN         NaN                     NaN
# 504         NaN                     NaN         NaN                     NaN
# 505         NaN                     NaN         NaN                     NaN
# 506         NaN                     NaN         NaN                     NaN
# 507         NaN                     NaN         NaN                     NaN
#
#
#     scale60 ID          scale60 labels scale33 ID        scale33 labels
# 0         65.0  lateralorbitofrontal_1       42.0  lateralorbitofrontal
# 1         66.0  lateralorbitofrontal_2       43.0         parsorbitalis
# 2         67.0         parsorbitalis_1       44.0           frontalpole
# 3         68.0           frontalpole_1       45.0   medialorbitofrontal
# 4         69.0   medialorbitofrontal_1       46.0      parstriangularis
# ..         ...                     ...        ...                   ...
# 503        NaN                     NaN        NaN                   NaN
# 504        NaN                     NaN        NaN                   NaN
# 505        NaN                     NaN        NaN                   NaN
# 506        NaN                     NaN        NaN                   NaN
# 507        NaN                     NaN        NaN                   NaN
#
# [508 rows x 20 columns]

# %%
splitted_rois = ut.split_lr_rois(regions)
assert splitted_rois.get('rh') == splitted_rois.get('lh')

# %%
all_labels_dict = {'atlas_right':rh_atlas_labels, 'data_right':splitted_rois.get('rh'), 'atlas_left':lh_atlas_labels, 'data_left':splitted_rois.get('lh') }
all_rois = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in all_labels_dict.items()]))
all_rois[-10:]
# Out:
#        atlas_right data_right      atlas_left data_left
# 55        insula_1   insula_1        insula_1  insula_1
# 56        insula_2   insula_2        insula_2  insula_2
# 57  thalamusproper        NaN  thalamusproper       NaN
# 58         caudate        NaN         caudate       NaN
# 59         putamen        NaN         putamen       NaN
# 60        pallidum        NaN        pallidum       NaN
# 61   accumbensarea        NaN   accumbensarea       NaN
# 62     hyppocampus        NaN     hyppocampus       NaN
# 63        amygdala        NaN        amygdala       NaN
# 64             NaN        NaN       brainstem       NaN
