# %%
import numpy as np
import glob
from matplotlib import pyplot as plt

# %%
data_path = ("/home/localadmin/Bureau/HUGO/Hugo/timeseries/")

# %%
os.listdir(data_path)
# Out:
# ['scale4', 'scale2', 'scale3', 'scale1', 'scale5']

# %%
timeserie_files = {"scale{}".format(i) : glob.glob(data_path + "scale{}/".format(i) + "*.npy",recursive=True) for i in [1, 2, 3, 4, 5,]}

# %%
for s in [1, 2, 3, 4, 5]:
    print("Nb of ROIs in timeserie :{}".format(np.load(timeserie_files.get('scale{}'.format(s))[0]).shape[0]))
# Out:
# Nb of ROIs in timeserie :126
# Nb of ROIs in timeserie :172
# Nb of ROIs in timeserie :277
# Nb of ROIs in timeserie :506
# Nb of ROIs in timeserie :1058

# %%
ts = np.load(timeserie_files.get('scale2'.format(s))[0])
plt.figure(figsize=(15,15))
plt.matshow(ts, fignum=0)
